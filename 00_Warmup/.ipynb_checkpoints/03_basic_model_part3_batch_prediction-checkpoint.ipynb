# %% [markdown]
# ## Batch Prediction
# ### Batch transform job
# If you have a file with the samples you want to predict, just upload that file to an S3 bucket and start a Batch Transform job. For this task, you don't need to deploy an endpoint. Sagemaker will create all the resources needed to do this batch prediction, save the results into an S3 bucket and then it will destroy the resources automatically for you

# %%
import sagemaker
import numpy as np
import boto3
import os
import pandas as pd
import io
from sklearn import datasets
from sagemaker import get_execution_role

role = get_execution_role()

iris = datasets.load_iris()
prefix='mlops/iris'
sagemaker_session = sagemaker.Session()
bucket = sagemaker_session.default_bucket()
model_name = open('model-name.txt', 'r').read().strip() if os.path.isfile('model-name.txt') else None
if model_name is None:
    raise Exception("You must run Part 1 or 2 before this. There you will train a Model to use here")

# %%
batch_dataset_filename="batch_dataset.csv"
np.savetxt(batch_dataset_filename, iris.data, delimiter=",", fmt='%0.3f')
input_batch = sagemaker_session.upload_data(path=batch_dataset_filename, key_prefix='%s/data' % prefix)

# %%
# Initialize the transformer object
transformer=sagemaker.transformer.Transformer(
    base_transform_job_name='mlops-iris',
    model_name=model_name,
    instance_count=1,
    instance_type='ml.c4.xlarge',
    output_path='s3://{}/{}/batch_output'.format(bucket, prefix),
)
# To start a transform job:
transformer.transform(input_batch, content_type='text/csv', split_type='Line')
# Then wait until transform job is completed
transformer.wait()
# Out:
# ............................[2022-08-31:19:12:16:INFO] No GPUs detected (normal if no gpus installed)
# [2022-08-31:19:12:16:INFO] No GPUs detected (normal if no gpus installed)
# [2022-08-31:19:12:16:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
# worker_rlimit_nofile 4096;
# [2022-08-31:19:12:16:INFO] No GPUs detected (normal if no gpus installed)
# [2022-08-31:19:12:16:INFO] No GPUs detected (normal if no gpus installed)
# [2022-08-31:19:12:16:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
# worker_rlimit_nofile 4096;
# events {
#   worker_connections 2048;
# }
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     keepalive_timeout 3;
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#     location / {
#       return 404 "{}";
#     }
#   }
# }
# [2022-08-31 19:12:16 +0000] [19] [INFO] Starting gunicorn 19.10.0
# [2022-08-31 19:12:16 +0000] [19] [INFO] Listening at: unix:/tmp/gunicorn.sock (19)
# [2022-08-31 19:12:16 +0000] [19] [INFO] Using worker: gevent
# [2022-08-31 19:12:16 +0000] [26] [INFO] Booting worker with pid: 26
# [2022-08-31 19:12:16 +0000] [27] [INFO] Booting worker with pid: 27
# [2022-08-31 19:12:16 +0000] [28] [INFO] Booting worker with pid: 28
# events {
#   worker_connections 2048;
# }
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     keepalive_timeout 3;
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#     location / {
#       return 404 "{}";
#     }
#   }
# }
# [2022-08-31 19:12:16 +0000] [19] [INFO] Starting gunicorn 19.10.0
# [2022-08-31 19:12:16 +0000] [19] [INFO] Listening at: unix:/tmp/gunicorn.sock (19)
# [2022-08-31 19:12:16 +0000] [19] [INFO] Using worker: gevent
# [2022-08-31 19:12:16 +0000] [26] [INFO] Booting worker with pid: 26
# [2022-08-31 19:12:16 +0000] [27] [INFO] Booting worker with pid: 27
# [2022-08-31 19:12:16 +0000] [28] [INFO] Booting worker with pid: 28
# [2022-08-31 19:12:16 +0000] [32] [INFO] Booting worker with pid: 32
# [2022-08-31 19:12:16 +0000] [32] [INFO] Booting worker with pid: 32
# [2022-08-31:19:12:21:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [31/Aug/2022:19:12:21 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2022-08-31:19:12:21:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [31/Aug/2022:19:12:21 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2022-08-31:19:12:21:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [31/Aug/2022:19:12:21 +0000] "POST /invocations HTTP/1.1" 200 600 "-" "Go-http-client/1.1"
# [2022-08-31:19:12:21:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [31/Aug/2022:19:12:21 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2022-08-31:19:12:21:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [31/Aug/2022:19:12:21 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2022-08-31:19:12:21:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [31/Aug/2022:19:12:21 +0000] "POST /invocations HTTP/1.1" 200 600 "-" "Go-http-client/1.1"
# 2022-08-31T19:12:21.922:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
#
# [2022-08-31:19:12:16:INFO] No GPUs detected (normal if no gpus installed)
# [2022-08-31:19:12:16:INFO] No GPUs detected (normal if no gpus installed)
# [2022-08-31:19:12:16:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
# worker_rlimit_nofile 4096;
# [2022-08-31:19:12:16:INFO] No GPUs detected (normal if no gpus installed)
# [2022-08-31:19:12:16:INFO] No GPUs detected (normal if no gpus installed)
# [2022-08-31:19:12:16:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
# worker_rlimit_nofile 4096;
# events {
#   worker_connections 2048;
# }
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     keepalive_timeout 3;
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#     location / {
#       return 404 "{}";
#     }
#   }
# }
# [2022-08-31 19:12:16 +0000] [19] [INFO] Starting gunicorn 19.10.0
# [2022-08-31 19:12:16 +0000] [19] [INFO] Listening at: unix:/tmp/gunicorn.sock (19)
# [2022-08-31 19:12:16 +0000] [19] [INFO] Using worker: gevent
# [2022-08-31 19:12:16 +0000] [26] [INFO] Booting worker with pid: 26
# [2022-08-31 19:12:16 +0000] [27] [INFO] Booting worker with pid: 27
# [2022-08-31 19:12:16 +0000] [28] [INFO] Booting worker with pid: 28
# events {
#   worker_connections 2048;
# }
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     keepalive_timeout 3;
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#     location / {
#       return 404 "{}";
#     }
#   }
# }
# [2022-08-31 19:12:16 +0000] [19] [INFO] Starting gunicorn 19.10.0
# [2022-08-31 19:12:16 +0000] [19] [INFO] Listening at: unix:/tmp/gunicorn.sock (19)
# [2022-08-31 19:12:16 +0000] [19] [INFO] Using worker: gevent
# [2022-08-31 19:12:16 +0000] [26] [INFO] Booting worker with pid: 26
# [2022-08-31 19:12:16 +0000] [27] [INFO] Booting worker with pid: 27
# [2022-08-31 19:12:16 +0000] [28] [INFO] Booting worker with pid: 28
# [2022-08-31 19:12:16 +0000] [32] [INFO] Booting worker with pid: 32
# [2022-08-31 19:12:16 +0000] [32] [INFO] Booting worker with pid: 32
# [2022-08-31:19:12:21:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [31/Aug/2022:19:12:21 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2022-08-31:19:12:21:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [31/Aug/2022:19:12:21 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2022-08-31:19:12:21:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [31/Aug/2022:19:12:21 +0000] "POST /invocations HTTP/1.1" 200 600 "-" "Go-http-client/1.1"
# [2022-08-31:19:12:21:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [31/Aug/2022:19:12:21 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2022-08-31:19:12:21:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [31/Aug/2022:19:12:21 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2022-08-31:19:12:21:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [31/Aug/2022:19:12:21 +0000] "POST /invocations HTTP/1.1" 200 600 "-" "Go-http-client/1.1"
# 2022-08-31T19:12:21.922:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD

# %%
dataset = np.insert(iris.data, 0, iris.target, axis=1)
df = pd.DataFrame(data=dataset, columns=['iris_id']+iris.feature_names)

df_pred = pd.read_csv(io.StringIO(
    sagemaker_session.read_s3_file(bucket, '{}/batch_output/{}.out'.format(prefix, 
                                                                       batch_dataset_filename))), 
                     names=['predicted_iris_id'])
df = pd.merge(df, df_pred, left_index=True, right_index=True)
df.head()
# Out:
#    iris_id  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0      0.0                5.1               3.5                1.4
# 1      0.0                4.9               3.0                1.4
# 2      0.0                4.7               3.2                1.3
# 3      0.0                4.6               3.1                1.5
# 4      0.0                5.0               3.6                1.4
#
#    petal width (cm)  predicted_iris_id
# 0               0.2                0.0
# 1               0.2                0.0
# 2               0.2                0.0
# 3               0.2                0.0
# 4               0.2                0.0

# %%
from sklearn.metrics import f1_score
score = f1_score(df['iris_id'], df['predicted_iris_id'], labels=[0.0, 1.0, 2.0], average='micro')

print("F1 Score: %.1f"%(score*100))
# Out:
# F1 Score: 98.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import confusion_matrix

cnf_matrix = confusion_matrix(df['iris_id'], df['predicted_iris_id'])

f, ax = plt.subplots(figsize=(15,8))
sns.heatmap(cnf_matrix, annot=True, fmt='f', 
            mask=np.zeros_like(cnf_matrix, dtype=np.bool),
           cmap=sns.diverging_palette(220, 10, as_cmap=True),
           square=True, ax=ax)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>
